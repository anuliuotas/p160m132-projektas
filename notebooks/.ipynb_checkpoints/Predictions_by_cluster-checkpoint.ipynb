# %%
import json
import logging
import pathlib
import uuid
from pathlib import Path

import click
import pyspark
from dotenv import find_dotenv, load_dotenv
from pyspark.ml import classification
from pyspark.ml import evaluation
from pyspark.ml import feature
from pyspark.ml import pipeline

# %%
spark = (
        pyspark.sql.SparkSession
            .builder
            .appName("Python Spark Random Forest model training")
            .enableHiveSupport()
            .getOrCreate()
    )

# %%
! tree
# Out:
# .
# ├── aggregation_write_read.ipynb
# ├── cluster_analysis.ipynb
# ├── derby.log
# ├── Duomenu-zvalgomoji-analize.ipynb
# ├── fk_metric_usage_example.ipynb
# ├── klasteriu_interpretacija.ipynb
# ├── KMeans_clustering.ipynb
# ├── metastore_db
# │   ├── dbex.lck
# │   ├── db.lck
# │   ├── log
# │   │   ├── log1.dat
# │   │   ├── log.ctrl
# │   │   ├── logmirror.ctrl
# │   │   └── README_DO_NOT_TOUCH_FILES.txt
# │   ├── README_DO_NOT_TOUCH_FILES.txt
# │   ├── seg0
# │   │   ├── c101.dat
# │   │   ├── c10.dat
# │   │   ├── c111.dat
# │   │   ├── c121.dat
# │   │   ├── c130.dat
# │   │   ├── c141.dat
# │   │   ├── c150.dat
# │   │   ├── c161.dat
# │   │   ├── c171.dat
# │   │   ├── c180.dat
# │   │   ├── c191.dat
# │   │   ├── c1a1.dat
# │   │   ├── c1b1.dat
# │   │   ├── c1c0.dat
# │   │   ├── c1d1.dat
# │   │   ├── c1e0.dat
# │   │   ├── c1f1.dat
# │   │   ├── c200.dat
# │   │   ├── c20.dat
# │   │   ├── c211.dat
# │   │   ├── c221.dat
# │   │   ├── c230.dat
# │   │   ├── c241.dat
# │   │   ├── c251.dat
# │   │   ├── c260.dat
# │   │   ├── c271.dat
# │   │   ├── c281.dat
# │   │   ├── c290.dat
# │   │   ├── c2a1.dat
# │   │   ├── c2b1.dat
# │   │   ├── c2c1.dat
# │   │   ├── c2d0.dat
# │   │   ├── c2e1.dat
# │   │   ├── c2f0.dat
# │   │   ├── c300.dat
# │   │   ├── c311.dat
# │   │   ├── c31.dat
# │   │   ├── c321.dat
# │   │   ├── c331.dat
# │   │   ├── c340.dat
# │   │   ├── c351.dat
# │   │   ├── c361.dat
# │   │   ├── c371.dat
# │   │   ├── c380.dat
# │   │   ├── c391.dat
# │   │   ├── c3a1.dat
# │   │   ├── c3b1.dat
# │   │   ├── c3c0.dat
# │   │   ├── c3d1.dat
# │   │   ├── c3e1.dat
# │   │   ├── c3f1.dat
# │   │   ├── c400.dat
# │   │   ├── c411.dat
# │   │   ├── c41.dat
# │   │   ├── c421.dat
# │   │   ├── c430.dat
# │   │   ├── c441.dat
# │   │   ├── c451.dat
# │   │   ├── c461.dat
# │   │   ├── c470.dat
# │   │   ├── c481.dat
# │   │   ├── c490.dat
# │   │   ├── c4a1.dat
# │   │   ├── c4b0.dat
# │   │   ├── c4c1.dat
# │   │   ├── c4d1.dat
# │   │   ├── c4e1.dat
# │   │   ├── c4f0.dat
# │   │   ├── c501.dat
# │   │   ├── c510.dat
# │   │   ├── c51.dat
# │   │   ├── c521.dat
# │   │   ├── c530.dat
# │   │   ├── c541.dat
# │   │   ├── c550.dat
# │   │   ├── c561.dat
# │   │   ├── c570.dat
# │   │   ├── c581.dat
# │   │   ├── c590.dat
# │   │   ├── c5a1.dat
# │   │   ├── c5b0.dat
# │   │   ├── c5c1.dat
# │   │   ├── c5d0.dat
# │   │   ├── c5e1.dat
# │   │   ├── c5f0.dat
# │   │   ├── c601.dat
# │   │   ├── c60.dat
# │   │   ├── c610.dat
# │   │   ├── c621.dat
# │   │   ├── c630.dat
# │   │   ├── c641.dat
# │   │   ├── c650.dat
# │   │   ├── c661.dat
# │   │   ├── c670.dat
# │   │   ├── c681.dat
# │   │   ├── c690.dat
# │   │   ├── c6a1.dat
# │   │   ├── c6b0.dat
# │   │   ├── c6c1.dat
# │   │   ├── c6d0.dat
# │   │   ├── c6e1.dat
# │   │   ├── c6f0.dat
# │   │   ├── c701.dat
# │   │   ├── c711.dat
# │   │   ├── c71.dat
# │   │   ├── c721.dat
# │   │   ├── c731.dat
# │   │   ├── c741.dat
# │   │   ├── c751.dat
# │   │   ├── c761.dat
# │   │   ├── c771.dat
# │   │   ├── c781.dat
# │   │   ├── c791.dat
# │   │   ├── c7a1.dat
# │   │   ├── c7b1.dat
# │   │   ├── c7c1.dat
# │   │   ├── c7d1.dat
# │   │   ├── c7e1.dat
# │   │   ├── c7f1.dat
# │   │   ├── c801.dat
# │   │   ├── c811.dat
# │   │   ├── c81.dat
# │   │   ├── c821.dat
# │   │   ├── c831.dat
# │   │   ├── c840.dat
# │   │   ├── c851.dat
# │   │   ├── c860.dat
# │   │   ├── c871.dat
# │   │   ├── c880.dat
# │   │   ├── c891.dat
# │   │   ├── c8a0.dat
# │   │   ├── c8b1.dat
# │   │   ├── c8c1.dat
# │   │   ├── c8d1.dat
# │   │   ├── c8e1.dat
# │   │   ├── c8f1.dat
# │   │   ├── c901.dat
# │   │   ├── c90.dat
# │   │   ├── c911.dat
# │   │   ├── c920.dat
# │   │   ├── c931.dat
# │   │   ├── c940.dat
# │   │   ├── c951.dat
# │   │   ├── c960.dat
# │   │   ├── c971.dat
# │   │   ├── c981.dat
# │   │   ├── c990.dat
# │   │   ├── c9a1.dat
# │   │   ├── c9b1.dat
# │   │   ├── c9c0.dat
# │   │   ├── c9d1.dat
# │   │   ├── c9e0.dat
# │   │   ├── c9f1.dat
# │   │   ├── ca01.dat
# │   │   ├── ca11.dat
# │   │   ├── ca1.dat
# │   │   ├── ca21.dat
# │   │   ├── cb1.dat
# │   │   ├── cc0.dat
# │   │   ├── cd1.dat
# │   │   ├── ce1.dat
# │   │   ├── cf0.dat
# │   │   └── README_DO_NOT_TOUCH_FILES.txt
# │   ├── service.properties
# │   └── tmp
# ├── multiple_csv_join.ipynb
# ├── Predictions_by_cluster.ipynb
# └── simple_clustering.ipynb
#
# 4 directories, 181 files

# %%
data_path = '../data/output/k_means/clustered_kmeans__k_5_parquet/'

# %%
data_df = spark.read.parquet(data_path)

gr = data_df.groupby(['prediction'])
clusters = data_df.select('prediction').distinct().toPandas()
for index, row in clusters.iterrows():
    cluster_index = row['prediction']
    cluster_df = data_df.filter(data_df.prediction == cluster_index.item())
# Out:
# 38806
# 38806

# %%
splits = data_df.randomSplit([0.7, 0.3])
training_df = splits[0]
validation_df = splits[1]

# %%
# Out:
# 5485
