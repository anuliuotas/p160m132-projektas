# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import os
import operator

import jsonlines
import pandas as pd
import pyspark
from pyspark.ml.feature import VectorAssembler, StandardScaler
from pyspark.ml.pipeline import Pipeline
from pyspark.ml.clustering import KMeans, GaussianMixture

# %%
spark = (
    pyspark.sql.SparkSession
    .builder
    .appName("Python Spark cluster analysis")
    .enableHiveSupport()
    .getOrCreate()
)

# %%
path_aggregated_df = "../data/output/k_means/clustered_kmeans__k_7_parquet/"

# %%
clustering_df = spark.read.parquet(path_aggregated_df)

clustering_df
# Out:
# DataFrame[user_account_id: int, _c0: double, user_lifetime: double, user_no_outgoing_activity_in_days: double, user_account_balance_last: double, user_spendings: double, reloads_inactive_days: double, reloads_count: double, reloads_sum: double, calls_outgoing_count: double, calls_outgoing_spendings: double, calls_outgoing_duration: double, calls_outgoing_spendings_max: double, calls_outgoing_duration_max: double, calls_outgoing_inactive_days: double, calls_outgoing_to_onnet_count: double, calls_outgoing_to_onnet_spendings: double, calls_outgoing_to_onnet_duration: double, calls_outgoing_to_onnet_inactive_days: double, calls_outgoing_to_offnet_count: double, calls_outgoing_to_offnet_spendings: double, calls_outgoing_to_offnet_duration: double, calls_outgoing_to_offnet_inactive_days: double, calls_outgoing_to_abroad_count: double, calls_outgoing_to_abroad_spendings: double, calls_outgoing_to_abroad_duration: double, calls_outgoing_to_abroad_inactive_days: double, sms_outgoing_count: do
# ...

# %%
df = clustering_df.toPandas()
df.head(5)
# Out:
#    user_account_id           _c0  user_lifetime  \
# 0           944511  69239.333333          340.0
# 1           355709  69646.666667         1285.0
# 2          1121526  69731.666667           74.0
# 3           393129  69891.000000          892.0
# 4           390590  70101.333333         1229.0
#
#    user_no_outgoing_activity_in_days  user_account_balance_last  \
# 0                           7.333333                   9.766667
# 1                           5.666667                   0.000000
# 2                           2.000000                  16.353333
# 3                           3.666667                   4.410000
# 4                           0.666667                   3.523333
#
#    user_spendings  reloads_inactive_days  reloads_count  reloads_sum  \
# 0        7.760000             474.333333       0.333333     0.500000
# 1        2.000000              48.000000       0.333333     2.000000
# 2        4.526667              35.666667       0.666667     8.006667
# ...

# %%
df.describe(include="all")
# Out:
#         user_account_id            _c0  user_lifetime  \
# count      3.880600e+04   38806.000000   38806.000000
# unique              NaN            NaN            NaN
# top                 NaN            NaN            NaN
# freq                NaN            NaN            NaN
# mean       6.088175e+05   73300.502843    4020.006962
# std        4.355919e+05   21336.541021    5936.189849
# min        1.300000e+01   43235.666667       1.000000
# 25%        2.574325e+05   56826.916667     518.250000
# 50%        4.168255e+05   70371.833333    1282.000000
# 75%        1.106625e+06   83826.083333    2017.000000
# max        1.196944e+06  136301.000000   15947.000000
#
#         user_no_outgoing_activity_in_days  user_account_balance_last  \
# count                        38806.000000               38806.000000
# unique                                NaN                        NaN
# top                                   NaN                        NaN
# ...

# %%
grouped_df = df.groupby('prediction').describe(include="all")

# %%
df1 = grouped_df['user_account_id']
df1['pcc'] = df1['count'] / df1['count'].sum()
df1 = df1[['count', 'pcc']]

excluded = ['prediction', 'initial_features', 'features']
for col in df.columns:  
    if not col in excluded:
        df1[col] = grouped_df[col]['mean']
# Out:
# /home/majo/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df1
# Out:
#               count       pcc  user_account_id            _c0  user_lifetime  \
# prediction
# 0           15599.0  0.401974     4.720782e+05   67170.400816    1359.946663
# 1            6136.0  0.158120     1.187332e+06  107302.783219   15929.473571
# 2             615.0  0.015848     7.844440e+05   66320.362060    9240.959892
# 3           10603.0  0.273231     5.196516e+05   66197.607658    2248.459288
# 4            3861.0  0.099495     5.036081e+05   67410.345291    1197.030735
# 5            1288.0  0.033191     5.477238e+05   68582.151786    1607.384187
# 6             704.0  0.018142     4.746502e+05   66779.746922    1175.684186
#
#             user_no_outgoing_activity_in_days  user_account_balance_last  \
# prediction
# 0                                    2.990865                  10.232788
# 1                                    8.310246                   0.407790
# 2                                  430.278591                   4.698130
# ...
