# %%
import pathlib
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import plotnine as gg
import click
import logging
from pathlib import Path
import pandas as pd
import pathlib
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import pylab
from pylab import xticks

# %%
path_customer_churn1 = pathlib.Path("../data/raw/customer_churn_0005.csv")
customer_churn1 = pd.read_csv(path_customer_churn1, delimiter=",")
len(customer_churn1)
# Out:
# 49693

# %%
path_customer_usage1 = pathlib.Path("../data/raw/customer_usage_0005.csv")
customer_usage1 = pd.read_csv(path_customer_usage1, delimiter=",")
len(customer_usage1)
# Out:
# 136302

# %%
path_customer_churn = pathlib.Path("../data/interim/customer_churn.csv")
path_customer_usage = pathlib.Path("../data/interim/customer_usage.csv")

# %%
customer_churn = pd.read_csv(path_customer_churn, delimiter=",")

# %%
customer_usage = pd.read_csv(path_customer_usage, delimiter=",")

# %%
customer_churn.describe(include="all")
# Out:
#          year   month  user_account_id        churn
# count  5061.0  5061.0     5.061000e+03  5061.000000
# mean   2013.0     9.0     5.937355e+05     0.205493
# std       0.0     0.0     4.294465e+05     0.404101
# min    2013.0     9.0     2.700000e+01     0.000000
# 25%    2013.0     9.0     2.453490e+05     0.000000
# 50%    2013.0     9.0     4.139200e+05     0.000000
# 75%    2013.0     9.0     1.041736e+06     0.000000
# max    2013.0     9.0     1.196933e+06     1.000000

# %%
customer_usage.describe(include="all")
# Out:
#           year         month  user_account_id  user_lifetime   user_intake  \
# count  13844.0  13844.000000     1.384400e+04   13844.000000  13844.000000
# mean    2013.0      7.049913     5.361070e+05    2743.831479      0.025571
# std        0.0      0.823888     4.056738e+05    4846.125488      0.157856
# min     2013.0      6.000000     2.700000e+01       0.000000      0.000000
# 25%     2013.0      6.000000     2.127060e+05     445.000000      0.000000
# 50%     2013.0      7.000000     3.957340e+05    1079.000000      0.000000
# 75%     2013.0      8.000000     9.868768e+05    1963.000000      0.000000
# max     2013.0      8.000000     1.196933e+06   15947.000000      1.000000
#
#        user_no_outgoing_activity_in_days  user_account_balance_last  \
# count                       13844.000000               13844.000000
# mean                           42.471034                  10.414656
# std                           216.267461                  14.132944
# min                             0.000000                   0.000000
# 25%                             1.000000                   0.890000
# 50%                             1.000000                   6.110000
# 75%                             5.000000                  13.890000
# max                          1307.000000                 218.350000
#
#        user_spendings  user_has_outgoing_calls  user_has_outgoing_sms  ...  \
# count    13844.000000             13844.000000           13844.000000  ...
# mean         7.306020                 0.890566               0.661658  ...
# std         14.187962                 0.312194               0.473162  ...
# min         -5.580000                 0.000000               0.000000  ...
# 25%          0.150000                 1.000000               0.000000  ...
# 50%          2.785000                 1.000000               1.000000  ...
# 75%          8.550000                 1.000000               1.000000  ...
# max        317.750000                 1.000000               1.000000  ...
#
#        last_100_reloads_sum  last_100_calls_outgoing_duration  \
# count          13844.000000                      13844.000000
# mean              23.862560                        109.154275
# std               41.177729                        206.398618
# min               -7.000000                          0.000000
# 25%                0.000000                          6.280000
# 50%               12.000000                         41.760000
# 75%               30.000000                        126.327500
# max              941.060000                       4129.250000
#
#        last_100_calls_outgoing_to_onnet_duration  \
# count                               13844.000000
# mean                                    1.415873
# std                                     8.215050
# min                                     0.000000
# 25%                                     0.000000
# 50%                                     0.000000
# 75%                                     0.000000
# max                                   348.950000
#
#        last_100_calls_outgoing_to_offnet_duration  \
# count                                13844.000000
# mean                                    72.973828
# std                                    163.907837
# min                                      0.000000
# 25%                                      1.000000
# 50%                                     21.080000
# 75%                                     78.180000
# max                                   3956.200000
#
#        last_100_calls_outgoing_to_abroad_duration  \
# count                                13844.000000
# mean                                     3.871051
# std                                     19.135336
# min                                      0.000000
# 25%                                      0.000000
# 50%                                      0.000000
# 75%                                      0.000000
# max                                    984.370000
#
#        last_100_sms_outgoing_count  last_100_sms_outgoing_to_onnet_count  \
# count                 13844.000000                          13844.000000
# mean                    112.436723                              8.454565
# std                     255.196226                             34.741915
# min                       0.000000                              0.000000
# 25%                       1.000000                              0.000000
# 50%                      22.000000                              0.000000
# 75%                     112.000000                              2.000000
# max                    3970.000000                            934.000000
#
#        last_100_sms_outgoing_to_offnet_count  \
# count                           13844.000000
# mean                               68.706082
# std                               180.168112
# min                                 0.000000
# 25%                                 0.000000
# 50%                                 8.000000
# 75%                                60.000000
# max                              3861.000000
#
#        last_100_sms_outgoing_to_abroad_count  last_100_gprs_usage
# count                           13844.000000         13844.000000
# mean                                4.302875             9.008170
# std                                20.052433           131.293983
# min                                 0.000000             0.000000
# 25%                                 0.000000             0.000000
# 50%                                 0.000000             0.000000
# 75%                                 0.000000             0.000000
# max                               764.000000          7671.690000
#
# [8 rows x 65 columns]

# %%
descVar = customer_usage1.describe(include="all").T

# %%
describe = customer_churn1.describe(include="all")

# %%
import operator
import functools

import pyspark
import pandas as pd
import plotnine as gg
import IPython

import pyspark.sql.functions as sql_fn
from pyspark.ml import stat
from pyspark.ml import feature
from pyspark.sql.functions import col, countDistinct

# %%
spark = (
    pyspark.sql.SparkSession
    .builder
    .appName("PySpark IO examples")
    .enableHiveSupport()
    .getOrCreate()
)

# %%
customer_usage2 = customer_usage1.drop(columns=['year', 'user_account_id', 'month', 'user_intake', 'calls_outgoing_to_onnet_inactive_days', 
                                                'calls_outgoing_to_offnet_inactive_days','calls_outgoing_to_abroad_inactive_days', 'sms_outgoing_to_onnet_inactive_days', 'sms_outgoing_to_offnet_inactive_days', 
                                                'sms_outgoing_to_abroad_inactive_days', 'sms_incoming_from_abroad_spendings','gprs_session_count', 
                                                'gprs_usage', 'gprs_spendings' ])

# %%
for col in customer_usage2.columns:
    path = "../reports/figures/" + col + ".png"
    q1 = customer_usage2.quantile(.02)[col]
    q2 = customer_usage2.quantile(.98)[col]
    
    
    hist = gg.ggplot(customer_usage1, gg.aes(x=col)) + gg.geom_histogram() + gg.scales.xlim(q1, q2)
    #print(age_hist + gg.theme_bw())
    hist.save(path)
# Out:
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/user_lifetime.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 270'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2714 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/user_no_outgoing_activity_in_days.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 8209'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 1857 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/user_account_balance_last.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 100'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2722 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/user_spendings.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 139'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2748 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/user_has_outgoing_calls.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/user_has_outgoing_sms.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 26'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/user_use_gprs.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/user_does_reload.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 26'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/reloads_inactive_days.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 28'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 1098 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/reloads_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 129'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 1893 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/reloads_sum.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 103'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2867 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 139'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2711 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_spendings.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 164'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2726 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_duration.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 151'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2726 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_spendings_max.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 143'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2503 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_duration_max.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 117'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2724 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_inactive_days.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 4919'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_to_onnet_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2659 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_to_onnet_spendings.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2722 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_to_onnet_duration.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2726 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_to_offnet_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 161'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2693 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_to_offnet_spendings.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 178'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2727 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_to_offnet_duration.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 184'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2726 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_to_abroad_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2638 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_to_abroad_spendings.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2723 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/calls_outgoing_to_abroad_duration.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2726 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/sms_outgoing_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 220'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2708 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/sms_outgoing_spendings.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 228'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2730 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/sms_outgoing_spendings_max.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 284'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2624 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/sms_outgoing_inactive_days.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 387'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/sms_outgoing_to_onnet_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2657 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/sms_outgoing_to_onnet_spendings.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2683 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/sms_outgoing_to_offnet_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 303'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2724 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/sms_outgoing_to_offnet_spendings.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 316'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2716 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/sms_outgoing_to_abroad_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2668 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/sms_outgoing_to_abroad_spendings.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2702 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/sms_incoming_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 93'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2717 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/sms_incoming_spendings.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 1938 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/sms_incoming_from_abroad_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 309'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2367 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/gprs_inactive_days.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 554'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2624 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/last_100_reloads_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 109'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2560 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/last_100_reloads_sum.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 114'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2849 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/last_100_calls_outgoing_duration.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 143'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2727 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/last_100_calls_outgoing_to_onnet_duration.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2725 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/last_100_calls_outgoing_to_offnet_duration.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 163'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2727 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/last_100_calls_outgoing_to_abroad_duration.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2727 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/last_100_sms_outgoing_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 197'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2723 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/last_100_sms_outgoing_to_onnet_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 1081'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2676 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/last_100_sms_outgoing_to_offnet_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 239'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2720 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/last_100_sms_outgoing_to_abroad_count.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2715 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:729: PlotnineWarning: Saving 6.4 x 4.8 in image.
#   from_inches(height, units), units), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\ggplot.py:730: PlotnineWarning: Filename: ../reports/figures/last_100_gprs_usage.png
#   warn('Filename: {}'.format(filename), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: PlotnineWarning: 'stat_bin()' using 'bins = 370'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']), PlotnineWarning)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:360: PlotnineWarning: stat_bin : Removed 2727 rows containing non-finite values.
#   data = self.stat.compute_layer(data, params, layout)
# C:\Users\edgad\Anaconda3\lib\site-packages\plotnine\layer.py:452: PlotnineWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)

# %%
q = customer_usage1.quantile([.05, .95]).T
corr_usage1 = customer_usage2.corr(method ='pearson') 
specific_dir = "../data/output/zvalgomoji/"
q.to_csv(specific_dir+'/VariablesQuantiles.csv')
corr_usage1.to_csv(specific_dir+'/VariablesCorr.csv')

# %%
descVar.to_csv(specific_dir+'/VariablesDesc.csv')

# %%
specific_dir = "../data/output/zvalgomoji/"
customer_usage2.to_csv(specific_dir+'/dataspark.csv')

# %%
specific_dir = "../data/output/zvalgomoji/"
customer_usage1.to_csv(specific_dir+'/datasparkVisas.csv')

# %%
customer_usage21 = spark.read.csv(
    "../data/output/zvalgomoji/dataspark.csv", 
    inferSchema=True, 
    header=True)

# %%
customer_usage1Visas = spark.read.csv(
    "../data/output/zvalgomoji/datasparkVisas.csv", 
    inferSchema=True, 
    header=True)

# %%
column_quantiles = customer_usage1Visas.columns
column_quantiles
# Out:
# ['_c0',
#  'year',
#  'month',
#  'user_account_id',
#  'user_lifetime',
#  'user_intake',
#  'user_no_outgoing_activity_in_days',
#  'user_account_balance_last',
#  'user_spendings',
#  'user_has_outgoing_calls',
#  'user_has_outgoing_sms',
#  'user_use_gprs',
#  'user_does_reload',
#  'reloads_inactive_days',
#  'reloads_count',
#  'reloads_sum',
#  'calls_outgoing_count',
#  'calls_outgoing_spendings',
#  'calls_outgoing_duration',
#  'calls_outgoing_spendings_max',
#  'calls_outgoing_duration_max',
#  'calls_outgoing_inactive_days',
#  'calls_outgoing_to_onnet_count',
#  'calls_outgoing_to_onnet_spendings',
#  'calls_outgoing_to_onnet_duration',
#  'calls_outgoing_to_onnet_inactive_days',
#  'calls_outgoing_to_offnet_count',
#  'calls_outgoing_to_offnet_spendings',
#  'calls_outgoing_to_offnet_duration',
#  'calls_outgoing_to_offnet_inactive_days',
#  'calls_outgoing_to_abroad_count',
#  'calls_outgoing_to_abroad_spendings',
#  'calls_outgoing_to_abroad_duration',
#  'calls_outgoing_to_abroad_inactive_days',
#  'sms_outgoing_count',
#  'sms_outgoing_spendings',
#  'sms_outgoing_spendings_max',
#  'sms_outgoing_inactive_days',
#  'sms_outgoing_to_onnet_count',
#  'sms_outgoing_to_onnet_spendings',
#  'sms_outgoing_to_onnet_inactive_days',
#  'sms_outgoing_to_offnet_count',
#  'sms_outgoing_to_offnet_spendings',
#  'sms_outgoing_to_offnet_inactive_days',
#  'sms_outgoing_to_abroad_count',
#  'sms_outgoing_to_abroad_spendings',
#  'sms_outgoing_to_abroad_inactive_days',
#  'sms_incoming_count',
#  'sms_incoming_spendings',
#  'sms_incoming_from_abroad_count',
#  'sms_incoming_from_abroad_spendings',
#  'gprs_session_count',
#  'gprs_usage',
#  'gprs_spendings',
#  'gprs_inactive_days',
#  'last_100_reloads_count',
#  'last_100_reloads_sum',
#  'last_100_calls_outgoing_duration',
#  'last_100_calls_outgoing_to_onnet_duration',
#  'last_100_calls_outgoing_to_offnet_duration',
#  'last_100_calls_outgoing_to_abroad_duration',
#  'last_100_sms_outgoing_count',
#  'last_100_sms_outgoing_to_onnet_count',
#  'last_100_sms_outgoing_to_offnet_count',
#  'last_100_sms_outgoing_to_abroad_count',
#  'last_100_gprs_usage']

# %%
column_quantiles = [
 'user_lifetime','user_no_outgoing_activity_in_days','user_account_balance_last',
 'user_spendings','reloads_inactive_days','reloads_sum', 'calls_outgoing_duration',
 'calls_outgoing_inactive_days','calls_outgoing_to_onnet_inactive_days','calls_outgoing_to_offnet_inactive_days',
 'calls_outgoing_to_abroad_inactive_days','sms_outgoing_count','sms_outgoing_spendings','sms_outgoing_inactive_days',
 'sms_outgoing_to_onnet_inactive_days','sms_outgoing_to_offnet_spendings','sms_outgoing_to_offnet_inactive_days',
 'sms_outgoing_to_abroad_spendings','sms_outgoing_to_abroad_inactive_days','sms_incoming_spendings',
 'gprs_usage','gprs_spendings','gprs_inactive_days','last_100_reloads_sum']
column_quantiles
# Out:
# ['user_lifetime',
#  'user_no_outgoing_activity_in_days',
#  'user_account_balance_last',
#  'user_spendings',
#  'reloads_inactive_days',
#  'reloads_sum',
#  'calls_outgoing_duration',
#  'calls_outgoing_inactive_days',
#  'calls_outgoing_to_onnet_inactive_days',
#  'calls_outgoing_to_offnet_inactive_days',
#  'calls_outgoing_to_abroad_inactive_days',
#  'sms_outgoing_count',
#  'sms_outgoing_spendings',
#  'sms_outgoing_inactive_days',
#  'sms_outgoing_to_onnet_inactive_days',
#  'sms_outgoing_to_offnet_spendings',
#  'sms_outgoing_to_offnet_inactive_days',
#  'sms_outgoing_to_abroad_spendings',
#  'sms_outgoing_to_abroad_inactive_days',
#  'sms_incoming_spendings',
#  'gprs_usage',
#  'gprs_spendings',
#  'gprs_inactive_days',
#  'last_100_reloads_sum']

# %%
probabilities = [0.02, 0.95, 0.98]
relative_error_quantile = 0.01

column_quantiles= [
    (column , customer_usage1Visas.approxQuantile(column, probabilities, relative_error_quantile),)
    for column in column_quantiles
]
column_quantiles
# Out:
# [('user_lifetime', [51.0, 15947.0, 15947.0]),
#  ('user_no_outgoing_activity_in_days', [0.0, 48.0, 1276.0]),
#  ('user_account_balance_last', [0.0, 33.99, 44.17]),
#  ('user_spendings', [0.0, 26.63, 282.72]),
#  ('reloads_inactive_days', [1.0, 1338.0, 1338.0]),
#  ('reloads_sum', [0.0, 34.0, 233.38]),
#  ('calls_outgoing_duration', [0.0, 133.9, 1273.73]),
#  ('calls_outgoing_inactive_days', [0.0, 1276.0, 1338.0]),
#  ('calls_outgoing_to_onnet_inactive_days', [0.0, 1276.0, 1338.0]),
#  ('calls_outgoing_to_offnet_inactive_days', [0.0, 1276.0, 1338.0]),
#  ('calls_outgoing_to_abroad_inactive_days', [0.0, 1276.0, 1338.0]),
#  ('sms_outgoing_count', [0.0, 158.0, 2305.0]),
#  ('sms_outgoing_spendings', [0.0, 8.1, 13.08]),
#  ('sms_outgoing_inactive_days', [0.0, 1338.0, 1338.0]),
#  ('sms_outgoing_to_onnet_inactive_days', [0.0, 1338.0, 1338.0]),
#  ('sms_outgoing_to_offnet_spendings', [0.0, 5.7, 9.48]),
#  ('sms_outgoing_to_offnet_inactive_days', [0.0, 1338.0, 1338.0]),
#  ('sms_outgoing_to_abroad_spendings', [0.0, 0.81, 2.38]),
#  ('sms_outgoing_to_abroad_inactive_days', [0.0, 1338.0, 1338.0]),
#  ('sms_incoming_spendings', [0.0, 0.09, 1.56]),
#  ('gprs_usage', [0.0, 0.39, 9.13]),
#  ('gprs_spendings', [0.0, 0.0, 97.45]),
#  ('gprs_inactive_days', [7.0, 1338.0, 1338.0]),
#  ('last_100_reloads_sum', [0.0, 84.06, 120.0])]

# %%
column_quantiles_98 = [
    (column, quantiles[-1],)
    for column, quantiles
    in column_quantiles
]

## suranda tarp 2 ir 98 kvantilio duomenis

# %%
quantile_filters = [
    customer_usage1Visas[column] <= quantile
    for column, quantile
    in column_quantiles_98
]

# %%
merged_quantile_filter = functools.reduce(operator.and_, quantile_filters)
merged_quantile_filter
# Out:
# Column<b'((((((((((((((((((((((((user_lifetime <= 15947.0) AND (user_no_outgoing_activity_in_days <= 1276.0)) AND (user_account_balance_last <= 44.17)) AND (user_spendings <= 282.72)) AND (reloads_inactive_days <= 1338.0)) AND (reloads_sum <= 233.38)) AND (calls_outgoing_duration <= 1273.73)) AND (calls_outgoing_inactive_days <= 1338.0)) AND (calls_outgoing_to_onnet_inactive_days <= 1338.0)) AND (calls_outgoing_to_offnet_inactive_days <= 1338.0)) AND (calls_outgoing_to_abroad_inactive_days <= 1338.0)) AND (sms_outgoing_count <= 2305.0)) AND (sms_outgoing_spendings <= 13.08)) AND (sms_outgoing_inactive_days <= 1338.0)) AND (sms_outgoing_to_onnet_inactive_days <= 1338.0)) AND (sms_outgoing_to_offnet_spendings <= 9.48)) AND (sms_outgoing_to_offnet_inactive_days <= 1338.0)) AND (sms_outgoing_to_abroad_spendings <= 2.38)) AND (sms_outgoing_to_abroad_inactive_days <= 1338.0)) AND (sms_incoming_spendings <= 1.56)) AND (gprs_usage <= 9.13)) AND (gprs_spendings <= 97.45)) AND (gprs_inactive_days <= 1338.0)) AND (last_100_reloads_sum <= 120.0))'>

# %%
filtered_customer_usage21 = customer_usage1Visas.where(merged_quantile_filter)

# %%
filtered_customer_usage21.count()
# Out:
# 117771

# %%
ismesti_df = customer_usage1Visas.subtract(filtered_customer_usage21)

# %%
ismesti_df.count()
# Out:
# 18531

# %%
customer_usage1Visas.select(countDistinct("user_account_id")).show()
# Out:
# +-------------------------------+
# |count(DISTINCT user_account_id)|
# +-------------------------------+
# |                          49693|
# +-------------------------------+

# %%
customer_usage1Visas = customer_usage1Visas.join(ismesti_df, ("user_account_id"),'left_anti')
customer_usage1Visas.select(countDistinct("user_account_id")).show()
# Out:
# +-------------------------------+
# |count(DISTINCT user_account_id)|
# +-------------------------------+
# |                          38806|
# +-------------------------------+

# %%
customer_usage1Visas
print((customer_usage1Visas.count(), len(customer_usage1Visas.columns)))
# Out:
# (104009, 66)

# %%
customer_usage1Visas.coalesce(1).write.format("com.databricks.spark.csv").option("sep",";").option("header", "true").save("../data/processed/customer_usage_processed")
